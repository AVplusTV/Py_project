# %% [markdown]
# The version of the notebook server is: 6.1.4
#
# The server is running on this version of Python: Python 3.8.5
#
# OS Windows 10 Home
#
# Configurable nbextensions Table of Contents (2) compatibility: 4.x, 5.x (https://www.codegrepper.com/code-examples/shell/install+toc2+jupyter+notebook)

# %% [markdown]
# <b>Описание проекта:</b>
#
# <b>Прогнозирование температуры звезды</b>
#
# Вам пришла задача от обсерватории «Небо на ладони»: придумать, как с помощью нейросети определять температуру на поверхности обнаруженных звёзд.
#
# <b>Обычно для расчёта температуры учёные пользуются следующими методами:</b>
#
# * Закон смещения Вина.
#
# * Закон Стефана-Больцмана.
#
# * Спектральный анализ.
#
# Каждый из них имеет плюсы и минусы. Обсерватория хочет внедрить технологии машинного обучения для предсказания температуры звёзд, надеясь, что этот метод будет наиболее точным и удобным.
#
# В базе обсерватории есть характеристики уже изученных 240 звёзд.

# %% [markdown]
# Импортируем модули и библиотеки:

# %%
import pandas as pd # импорт библиотеки pandas
import matplotlib.pyplot as plt # импорт библиотеки работы с графиками
import numpy as np # импорт библиотеки для вычислений
import warnings

warnings.filterwarnings('ignore') # отключаем сообщения об ошибках pandas
pd.set_option('display.max_columns', None) # Сброс ограничений на число выводимых столбцов

from sklearn.model_selection import train_test_split # импорт метода для разделения таблицы
from sklearn.preprocessing import StandardScaler # импорт метода для массштабирования данных
import torch.nn as nn # импорт библиотеки для построения нейросети
import torch
from torchmetrics import MeanSquaredError as mse
from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_error as msem
import random
from math import ceil

# %% [markdown]
# ## Исследование данных

# %% [markdown]
# ### Открываем файл с данными и анализируем содержимое

# %% [markdown]
# Функция для чтения файла в таблицу с учетом возможности работы на разных платформах и заодно исследование данных в таблицах:

# %%
def read_csv(link):
    link1 = 'datasets/' + link
    link2 = '/datasets/' + link
    try:
        name_link = pd.read_csv(link1)
    except:
        name_link = pd.read_csv(link2)
    print('просмотрим первые пять строк')
    display(name_link.head())
    print('+++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
    print('просмотрим информацию')
    display(name_link.info())
    print('+++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
    print('посчитаем уникальные значения')
    display(name_link.nunique()) 
    print('+++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
    print('проверим имена столбцов')
    display(name_link.columns) 
    print('+++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
    print('проверка на явные дубликаты')
    display('Количество явных дубликатов:', name_link.duplicated().sum()) 
    print('+++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
    print('проверим численные данные')
    display(name_link.describe()) 
    print('+++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
    print('проверим корреляции')
    display(name_link.corr())
    print('+++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
    return name_link

# %%
df = read_csv('6_class.csv')
# Out:
# просмотрим первые пять строк
#    Unnamed: 0  Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  \
# 0           0             3068          0.002400        0.1700
# 1           1             3042          0.000500        0.1542
# 2           2             2600          0.000300        0.1020
# 3           3             2800          0.000200        0.1600
# 4           4             1939          0.000138        0.1030
#
#    Absolute magnitude(Mv)  Star type Star color
# 0                   16.12          0        Red
# 1                   16.60          0        Red
# 2                   18.70          0        Red
# 3                   16.65          0        Red
# 4                   20.06          0        Red
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# просмотрим информацию
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              240 non-null    int64
#  1   Temperature (K)         240 non-null    int64
#  2   Luminosity(L/Lo)        240 non-null    float64
#  3   Radius(R/Ro)            240 non-null    float64
#  4   Absolute magnitude(Mv)  240 non-null    float64
#  5   Star type               240 non-null    int64
#  6   Star color              240 non-null    object
# dtypes: float64(3), int64(3), object(1)
# memory usage: 13.2+ KB
# None
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# посчитаем уникальные значения
# Unnamed: 0                240
# Temperature (K)           228
# Luminosity(L/Lo)          208
# Radius(R/Ro)              216
# Absolute magnitude(Mv)    228
# Star type                   6
# Star color                 19
# dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# проверим имена столбцов
# Index(['Unnamed: 0', 'Temperature (K)', 'Luminosity(L/Lo)', 'Radius(R/Ro)',
#        'Absolute magnitude(Mv)', 'Star type', 'Star color'],
#       dtype='object')
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# проверка на явные дубликаты
# 'Количество явных дубликатов:'
# 0
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# проверим численные данные
#        Unnamed: 0  Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  \
# count   240.00000       240.000000        240.000000    240.000000
# mean    119.50000     10497.462500     107188.361635    237.157781
# std      69.42622      9552.425037     179432.244940    517.155763
# min       0.00000      1939.000000          0.000080      0.008400
# 25%      59.75000      3344.250000          0.000865      0.102750
# 50%     119.50000      5776.000000          0.070500      0.762500
# 75%     179.25000     15055.500000     198050.000000     42.750000
# max     239.00000     40000.000000     849420.000000   1948.500000
#
#        Absolute magnitude(Mv)   Star type
# count              240.000000  240.000000
# mean                 4.382396    2.500000
# std                 10.532512    1.711394
# min                -11.920000    0.000000
# 25%                 -6.232500    1.000000
# 50%                  8.313000    2.500000
# 75%                 13.697500    4.000000
# max                 20.060000    5.000000
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# проверим корреляции
#                         Unnamed: 0  Temperature (K)  Luminosity(L/Lo)  \
# Unnamed: 0                1.000000         0.391056          0.322719
# Temperature (K)           0.391056         1.000000          0.393404
# Luminosity(L/Lo)          0.322719         0.393404          1.000000
# Radius(R/Ro)              0.167608         0.064216          0.526516
# Absolute magnitude(Mv)   -0.257015        -0.420261         -0.692619
# Star type                 0.246505         0.411129          0.676845
#
#                         Radius(R/Ro)  Absolute magnitude(Mv)  Star type
# Unnamed: 0                  0.167608               -0.257015   0.246505
# Temperature (K)             0.064216               -0.420261   0.411129
# Luminosity(L/Lo)            0.526516               -0.692619   0.676845
# Radius(R/Ro)                1.000000               -0.608728   0.660975
# Absolute magnitude(Mv)     -0.608728                1.000000  -0.955276
# Star type                   0.660975               -0.955276   1.000000
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# Таблица содержит 240 строк - маловато данных для нормального обучения нейросети
#
# колонка Unnamed: 0 явно дублирует индексы ее можно удалить
#
#
# <b>Признаки для обучения</b>
#
#
# Luminosity(L/Lo) - Относительная светимость L/Lo — светимость звезды относительно Солнца. ТИП - float64
#
# Radius(R/Ro) - Относительный радиус R/Ro — радиус звезды относительно радиуса Солнца.ТИП - float64
#
# Absolute magnitude(Mv)  - Абсолютная звёздная величина Mv — физическая величина, характеризующая блеск звезды.ТИП - float64
#
# Star color - Звёздный цвет (white, red, blue, yellow, yellow-orange и др.) — цвет звезды, который определяют на основе спектрального анализа. ТИП  - object
#
# Star type - Тип звезды. ТИП - int64
# ![image-2.png](attachment:image-2.png)
#
#
#
#
#
# <b>Целевой признак</b>
#
# Temperature (K) - Абсолютная температура T(K) — температура на поверхности звезды в Кельвинах. ТИП - int64

# %% [markdown]
# ### Посмотрим на распределения: Построение гистограмм

# %%
plt.hist(df['Temperature (K)'], range = (0, 40000), bins=100, label = 'Temperature (K)')
plt.ylabel('Частотность')
plt.xlabel('Temperature (K)')
plt.legend()
plt.grid()

# %% [markdown]
# <b>Большинство звезд с температурой около 3000 К

# %% [markdown]
# Посчитаем количество строк с температурами ну скажем выше 20000 К

# %%
display(df[df['Temperature (K)'] >20000].count())
# Out:
# Unnamed: 0                40
# Temperature (K)           40
# Luminosity(L/Lo)          40
# Radius(R/Ro)              40
# Absolute magnitude(Mv)    40
# Star type                 40
# Star color                40
# dtype: int64

# %% [markdown]
# ТО есть 200 звезд до 20000 К и 40 звезд выше. Для горячих звезд явно будет не хватать обучающей выборки

# %%
plt.hist(df['Luminosity(L/Lo)'], range = (0, 850000), bins=150, label = 'Luminosity(L/Lo)')
plt.ylabel('Частотность')
plt.xlabel('Luminosity(L/Lo)')
plt.legend()
plt.grid()

# %% [markdown]
# <b>Явное скопление светимостей около нуля, помотрим пристальнее:

# %%
display(df[df['Luminosity(L/Lo)'] < 0.1])
# Out:
#      Unnamed: 0  Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  \
# 0             0             3068          0.002400       0.17000
# 1             1             3042          0.000500       0.15420
# 2             2             2600          0.000300       0.10200
# 3             3             2800          0.000200       0.16000
# 4             4             1939          0.000138       0.10300
# ..          ...              ...               ...           ...
# 205         205            19920          0.001560       0.01420
# 206         206            24020          0.001590       0.01270
# 207         207            23092          0.001320       0.01040
# 208         208            17920          0.001110       0.01060
# 209         209            19360          0.001250       0.00998
#
#      Absolute magnitude(Mv)  Star type Star color
# 0                     16.12          0        Red
# 1                     16.60          0        Red
# 2                     18.70          0        Red
# 3                     16.65          0        Red
# 4                     20.06          0        Red
# ..                      ...        ...        ...
# 205                   11.34          2       Blue
# 206                   10.55          2       Blue
# 207                   10.18          2       Blue
# 208                   11.66          2       Blue
# 209                   11.62          2       Blue
#
# [121 rows x 7 columns]

# %% [markdown]
# <b>Мда уж 209 из 240 звезд почти не светятся - тут весьма мало данных для ярких звезд

# %%
plt.hist(df['Radius(R/Ro)'], range = (0, 2000), bins=50, label = 'Radius(R/Ro)')
plt.ylabel('Частотность')
plt.xlabel('Radius(R/Ro)')
plt.legend()
plt.grid()

# %% [markdown]
# <b>Большинство звезд с радиусом близким к Солнцу или не сильно большие, посмотрим внимательнее

# %%
plt.hist(df['Radius(R/Ro)'], range = (0, 2), bins=50, label = 'Radius(R/Ro)')
plt.ylabel('Частотность')
plt.xlabel('Radius(R/Ro)')
plt.legend()
plt.grid()

# %% [markdown]
# Посмотрим на звезды меньше солнца

# %%
plt.hist(df['Radius(R/Ro)'], range = (0, 0.1), bins=50, label = 'Radius(R/Ro)')
plt.ylabel('Частотность')
plt.xlabel('Radius(R/Ro)')
plt.legend()
plt.grid()

# %%
plt.hist(df['Absolute magnitude(Mv)'], range = (-15, 21), bins=50, label = 'Absolute magnitude(Mv)')
plt.ylabel('Частотность')
plt.xlabel('Absolute magnitude(Mv)')
plt.legend()
plt.grid()

# %% [markdown]
# <b>Наблюдаются две области скопления показателей: в районе 15 и -7 Mv

# %%
plt.hist(df['Star type'], range = (0, 7), bins=7, label = 'Star type')
plt.ylabel('Частотность')
plt.xlabel('Star type')
plt.legend()
plt.grid()

# %% [markdown]
# сранный график, посчитаем уникальные значения.

# %%
df['Star type'].value_counts()
# Out:
# 5    40
# 4    40
# 3    40
# 2    40
# 1    40
# 0    40
# Name: Star type, dtype: int64

# %% [markdown]
# <b>Ну здесь вообще весьма странная подборка по типу - ибо другие данные явно тяготеют к  показателям Солнца и не наблюдается разбиение по показателям, а тут по типу как то одинаково разбиты данные - тут вполне возможно закралась ошибка в определении типов, искуственно как то. Хотя судя по корреляции этот параметр весьма хорошо влияет на температуру звезды.

# %% [markdown]
# ### Проверка на не явные дубликаты:

# %%
df['Star color'].unique()
# Out:
# array(['Red', 'Blue White', 'White', 'Yellowish White', 'Blue white',
#        'Pale yellow orange', 'Blue', 'Blue-white', 'Whitish',
#        'yellow-white', 'Orange', 'White-Yellow', 'white', 'Blue ',
#        'yellowish', 'Yellowish', 'Orange-Red', 'Blue white ',
#        'Blue-White'], dtype=object)

# %% [markdown]
# Наблюдаются не явные дубликаты, следует переименовать некоторые значения, а именно приведем к следующим названиям:
#
# Whitish Это White
#
# Yellowish White - желтоватый, можно оставить просто Yellowish (тут же yellow-white и 'White-Yellow')
#
# ИТОГО:
#
# 'Red', 'Blue-White', 'White', 'Yellowish', 'Pale-Yellow-Orange', 'Blue', 'Orange', 'Orange-Red'
#
# 'Red', 'White', 'Pale yellow orange', 'Orange', 'white','Orange-Red'

# %% [markdown]
# ### <b>Выводы и замечания по анализу данных:</b>

# %% [markdown]
# * требуется переименование всех столбцов в формат snake_case (думаю единицы измерения вообще можно убрать из названий)
# * пропусков и пустых значений в даных не наблюдается
# * явных дубликатов нет
# * проблем с минимальными и максимальными значениями нет
# * температура хорошо коррелирует со всеми числовыми данными кроме относительного радиуса
# * есть не явные дубликаты - требуется переименование
# * столбец Unnamed: 0	можно удалить
# * 240 строк данных это очень мало, для обучения нейросети хорошо бы увеличить количество строк данных
# * в столбце Star color категориальные данные - требуется преобразование OHE
# * масштаб данных в столбцах различный - требуется массштабирование данных

# %% [markdown]
# ## Предобработка данных по результатам анализа

# %% [markdown]
# ### Удалим столбцы не влияющие на предсказания

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df.head()
# Out:
#    Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0             3068          0.002400        0.1700                   16.12
# 1             3042          0.000500        0.1542                   16.60
# 2             2600          0.000300        0.1020                   18.70
# 3             2800          0.000200        0.1600                   16.65
# 4             1939          0.000138        0.1030                   20.06
#
#    Star type Star color
# 0          0        Red
# 1          0        Red
# 2          0        Red
# 3          0        Red
# 4          0        Red

# %% [markdown]
# ### Переименование столбцов

# %%
display(df.columns)
# Out:
# Index(['Temperature (K)', 'Luminosity(L/Lo)', 'Radius(R/Ro)',
#        'Absolute magnitude(Mv)', 'Star type', 'Star color'],
#       dtype='object')

# %%
df.set_axis(['temperature', 'luminosity', 'radius', 'absolute_magnitude',
       'star_type', 'star_color'],axis = 'columns',inplace = True)

# %%
df.head()
# Out:
#    temperature  luminosity  radius  absolute_magnitude  star_type star_color
# 0         3068    0.002400  0.1700               16.12          0        Red
# 1         3042    0.000500  0.1542               16.60          0        Red
# 2         2600    0.000300  0.1020               18.70          0        Red
# 3         2800    0.000200  0.1600               16.65          0        Red
# 4         1939    0.000138  0.1030               20.06          0        Red

# %% [markdown]
# ### Удаление не явных дубликатов

# %% [markdown]
# Напишем функцию замены

# %%
def replace(column, lists, word):
    for i in lists:
        df[column] = df[column].str.replace(i, word)

# %%
replace('star_color', ['Blue White', 'Blue white', 'Blue-white', 'Blue white ', 'Blue-White '], 'Blue-White')

# %%
replace('star_color', ['Yellowish White', 'Whitish', 'yellow-white', 'White-Yellow', 'yellowish'], 'Yellowish')

# %%
replace('star_color', ['Blue '], 'Blue')

# %%
replace('star_color', ['white'], 'White')

# %%
replace('star_color', ['Pale yellow orange'], 'Pale-Yellow-Orange')

# %%
df['star_color'].unique()
# Out:
# array(['Red', 'Blue-White', 'White', 'Yellowish', 'Pale-Yellow-Orange',
#        'Blue', 'Orange', 'Orange-Red'], dtype=object)

# %% [markdown]
# Теперь все в порядке, OHE даст нужные результаты

# %%
df.head()
# Out:
#    temperature  luminosity  radius  absolute_magnitude  star_type star_color
# 0         3068    0.002400  0.1700               16.12          0        Red
# 1         3042    0.000500  0.1542               16.60          0        Red
# 2         2600    0.000300  0.1020               18.70          0        Red
# 3         2800    0.000200  0.1600               16.65          0        Red
# 4         1939    0.000138  0.1030               20.06          0        Red

# %% [markdown]
# Выводы: необходимая предобработка данных произведена, теперь можно приступать к разделению на выборки,преобразованию категориальных данных и массштабированию данных

# %% [markdown]
# ## Разделение на выбрки, OHE , массштабирование

# %% [markdown]
# ### Разделяем таблицу на признаки для обучения и на целевой признак

# %%
features = df.drop('temperature', axis=1)
target = df['temperature']

# %% [markdown]
# ### OHE для признаков

# %%
features_ohe = pd.get_dummies(features, columns=['star_color'], drop_first=True)
features_ohe.head()
# Out:
#    luminosity  radius  absolute_magnitude  star_type  star_color_Blue-White  \
# 0    0.002400  0.1700               16.12          0                      0
# 1    0.000500  0.1542               16.60          0                      0
# 2    0.000300  0.1020               18.70          0                      0
# 3    0.000200  0.1600               16.65          0                      0
# 4    0.000138  0.1030               20.06          0                      0
#
#    star_color_Orange  star_color_Orange-Red  star_color_Pale-Yellow-Orange  \
# 0                  0                      0                              0
# 1                  0                      0                              0
# 2                  0                      0                              0
# 3                  0                      0                              0
# 4                  0                      0                              0
#
#    star_color_Red  star_color_White  star_color_Yellowish
# 0               1                 0                     0
# 1               1                 0                     0
# 2               1                 0                     0
# 3               1                 0                     0
# 4               1                 0                     0

# %% [markdown]
# ### Выделяем данные для обученияи тестовые данные

# %%
x_train, x_test, y_train, y_test = train_test_split(features_ohe, target, test_size=0.2, shuffle=True, random_state=12345)

# %%
x_train.shape
# Out:
# (192, 11)

# %%
x_test.shape
# Out:
# (48, 11)

# %%
y_test.shape
# Out:
# (48,)

# %% [markdown]
# ### Масштабирование признаков

# %% [markdown]
# Обучение скейлера на тренировочной выборке

# %%
numeric = ['luminosity', 'radius', 'absolute_magnitude']

scaler = StandardScaler()

scaler.fit(x_train[numeric])
# Out:
# StandardScaler()

# %% [markdown]
# Масштабирование признаков

# %%
x_train[numeric] = scaler.transform(x_train[numeric])
x_test[numeric] = scaler.transform(x_test[numeric])

# %%
x_train.head()
# Out:
#      luminosity    radius  absolute_magnitude  star_type  \
# 139   -0.573535 -0.425464            0.869405          1
# 14    -0.573535 -0.425707            0.626075          1
# 67    -0.573535 -0.425810            1.071862          0
# 17    -0.573535 -0.425014            0.532295          1
# 148   -0.573535 -0.425983            0.915244          2
#
#      star_color_Blue-White  star_color_Orange  star_color_Orange-Red  \
# 139                      0                  0                      0
# 14                       0                  0                      0
# 67                       0                  0                      0
# 17                       0                  0                      0
# 148                      0                  0                      0
#
#      star_color_Pale-Yellow-Orange  star_color_Red  star_color_White  \
# 139                              0               1                 0
# 14                               0               1                 0
# 67                               0               1                 0
# 17                               0               1                 0
# 148                              0               0                 1
#
#      star_color_Yellowish
# 139                     0
# 14                      0
# 67                      0
# 17                      0
# 148                     0

# %% [markdown]
# данные подготовлены для построения модели нейросети

# %% [markdown]
# ##  Построение простой модели нейронной сети — baseline

# %% [markdown]
# ### Класс для задания архитектуры нейронной сети и параметры

# %%
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
torch.use_deterministic_algorithms(True)

class Net(nn.Module):
    def __init__(self, n_in_neurons, n_hidden_neurons_1, n_hidden_neurons_2, n_out_neurons):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(n_in_neurons, n_hidden_neurons_1)
        self.act1 = nn.Tanh()
        self.fc2 = nn.Linear(n_hidden_neurons_1, n_hidden_neurons_2)
        self.act2 = nn.ReLU()
        self.fc3 = nn.Linear(n_hidden_neurons_2, n_out_neurons)        
        self.act3 = nn.ReLU()
        
        # Инициализация весов
        nn.init.uniform_(self.fc1.weight, a=-1, b=1)
        nn.init.uniform_(self.fc1.bias, a=-1, b=3)
        nn.init.uniform_(self.fc2.weight, b=3)
        nn.init.uniform_(self.fc2.bias, a=-1)
        nn.init.uniform_(self.fc3.weight, b=2)
        nn.init.uniform_(self.fc3.bias, a=-1)

    def forward(self, x):
        x = self.fc1(x)
        x = self.act1(x)
        x = self.fc2(x)
        x = self.act2(x)
        x = self.fc3(x)
        x = self.act3(x)
        return x

# %% [markdown]
# Задаем количество нейронов

# %%
net = Net(11, 20, 20, 1)

# %% [markdown]
# Преобразование данных в тензоры

# %%
x_train_tensor = torch.FloatTensor(x_train.values)
x_test_tensor = torch.FloatTensor(x_test.values)
y_train_tensor = torch.FloatTensor(y_train.values)
y_test_tensor = torch.FloatTensor(y_test.values)

# %% [markdown]
# Оптимизация

# %%
optimizer = torch.optim.Adam(net.parameters(), lr=0.05)

# %% [markdown]
# Функция потерь

# %%
loss = nn.L1Loss()# инициализируйте функцию потерь

# %% [markdown]
# ### Прогон сети по эпохам обучения, нахождение предсказаний при минимуме RMSE

# %%
num_epochs = 4000
best_rmse = 10000
test_preds_best = 0

for epoch in range(num_epochs):
    optimizer.zero_grad()

    preds = net.forward(x_train_tensor).flatten()
    
    loss_value = loss(preds, y_train_tensor)
    
    loss_value.backward()

    optimizer.step()
    
    if epoch % 100 == 0 or epoch == num_epochs - 1:
        net.eval()
        test_preds = net.forward(x_test_tensor).flatten()
        
        rmse = mse()**0.5
        RMSE = rmse(test_preds, y_test_tensor)
    
        print(RMSE)
        
    if best_rmse > RMSE:
        best_rmse = torch.round(RMSE)
        test_preds_best = torch.round(test_preds)
        
print()        
print('Лучшее RMSE: ', best_rmse)
print()
print('Лучшее предсказание: ', test_preds_best)
print()
print('Тестовые данные: ', y_test_tensor)
# Out:
# tensor(15782.7490, grad_fn=<PowBackward0>)
# tensor(11260.9287, grad_fn=<PowBackward0>)
# tensor(7626.9502, grad_fn=<PowBackward0>)
# tensor(6614.5737, grad_fn=<PowBackward0>)
# tensor(6249.2754, grad_fn=<PowBackward0>)
# tensor(5679.6460, grad_fn=<PowBackward0>)
# tensor(5324.5146, grad_fn=<PowBackward0>)
# tensor(5062.0742, grad_fn=<PowBackward0>)
# tensor(4847.1670, grad_fn=<PowBackward0>)
# tensor(4614.7148, grad_fn=<PowBackward0>)
# tensor(4756.6372, grad_fn=<PowBackward0>)
# tensor(4750.6528, grad_fn=<PowBackward0>)
# tensor(4756.6626, grad_fn=<PowBackward0>)
# tensor(4729.7251, grad_fn=<PowBackward0>)
# tensor(4689.1470, grad_fn=<PowBackward0>)
# tensor(4614.9141, grad_fn=<PowBackward0>)
# tensor(4588.8481, grad_fn=<PowBackward0>)
# tensor(4615.9731, grad_fn=<PowBackward0>)
# tensor(4570.1836, grad_fn=<PowBackward0>)
# tensor(4489.1895, grad_fn=<PowBackward0>)
# tensor(4560.2871, grad_fn=<PowBackward0>)
# tensor(4524.8530, grad_fn=<PowBackward0>)
# tensor(4485.8838, grad_fn=<PowBackward0>)
# tensor(4490.3564, grad_fn=<PowBackward0>)
# tensor(4454.8188, grad_fn=<PowBackward0>)
# tensor(4425.4961, grad_fn=<PowBackward0>)
# tensor(4484.8315, grad_fn=<PowBackward0>)
# tensor(4479.4526, grad_fn=<PowBackward0>)
# tensor(4460.7812, grad_fn=<PowBackward0>)
# tensor(4556.9141, grad_fn=<PowBackward0>)
# tensor(4551.7622, grad_fn=<PowBackward0>)
# tensor(4594.9707, grad_fn=<PowBackward0>)
# tensor(4594.7886, grad_fn=<PowBackward0>)
# tensor(4605.3755, grad_fn=<PowBackward0>)
# tensor(4637.5249, grad_fn=<PowBackward0>)
# tensor(4558.9751, grad_fn=<PowBackward0>)
# tensor(4702.5396, grad_fn=<PowBackward0>)
# tensor(4861.2065, grad_fn=<PowBackward0>)
# tensor(4860.5859, grad_fn=<PowBackward0>)
# tensor(4945.5586, grad_fn=<PowBackward0>)
# tensor(4963.8159, grad_fn=<PowBackward0>)
#
# Лучшее RMSE:  tensor(4425., grad_fn=<RoundBackward0>)
#
# Лучшее предсказание:  tensor([34522., 34352.,  9867.,  3634.,  9631.,  2779., 16722., 15503., 19585.,
#          2778., 20176.,  3672.,  3185., 10168.,  3315., 13755., 11552.,  3628.,
#         10109.,  2916., 27053., 19349., 24021.,  5642., 27006., 13738., 34210.,
#         21389., 19598.,  3244.,  3577., 18245.,  3863., 17383.,  3564.,  3085.,
#          3895.,  3629.,  3689.,  3310.,  3693., 34396.,  2940.,  2918.,  2926.,
#         18413.,  5789., 14160.], grad_fn=<RoundBackward0>)
#
# Тестовые данные:  tensor([32489., 39000.,  9320.,  3834.,  9030.,  3218., 22012., 11250., 19860.,
#          3574., 18340.,  3614.,  3150.,  8250.,  3100., 25000.,  8945.,  3459.,
#          9700.,  2945., 27739., 17120., 11096.,  4980., 30839., 11000., 29560.,
#         16787.,  5752.,  3462.,  3826., 19360.,  3607., 24630.,  3615.,  2700.,
#          3570.,  3450.,  3490.,  2799.,  3650., 37800.,  2889.,  2774.,  3323.,
#         33421.,  7700., 13023.])

# %% [markdown]
# Эксперименты с разными параметрами, архитектурой выдавали RMSE 4000 - 6000. Если проанализировать  предсказания и тестовую выборку, то наиболее выпадающие результаты на высоких температурах, что логично по причине малого количества данных для горячих звезд.

# %% [markdown]
# ### Посмотрим на линейную регрессию CatBoostRegressor классического обучения

# %%
model_cr = CatBoostRegressor(silent=True)
model_cr.fit(x_train, y_train)
predictions_valid_cr = model_cr.predict(x_test) # получим предсказания модели на валидационной выборке
result_cr = round(msem(y_test, predictions_valid_cr)**0.5, 2)
print('RMSE CatBoostRegressor: ', result_cr)# RMSE
# Out:
# RMSE CatBoostRegressor:  5604.81

# %% [markdown]
# Точность классического обучения в итоге получается ниже, чем лучшие показатели нейросети.

# %% [markdown]
# ### Сравнение Факт - Прогноз, график.

# %%
index = np.arange(48)
values1 = y_test_tensor.tolist()
values2 = test_preds_best.tolist()
values3 = predictions_valid_cr.round()
plt.figure(figsize=(16, 8))
plt.title('График сравнения фактической и предсказанной температуры звезд. '
          'Нейронная сеть Torch и классическое обучение CatBoost')
plt.bar(index, values1, alpha=0.6, label='ФАКТ', width=0.9)
plt.bar(index, values2, alpha=0.7, label='ПРОГНОЗ Torch', width=0.6)
plt.bar(index, values3, alpha=0.8, label='ПРОГНОЗ CatBoost', width=0.3)
plt.legend()
plt.xlabel('Номер звезды')
plt.ylabel('Температура К')
plt.show();

# %% [markdown]
# Да хорошо видно, что прогноз по температурам близким к 3000-4000 К наиболее точен. При этом есть несколько звезд для которых как нейронная модель, так и классическое обучение дает очень не точные результаты - видимо параметры сильно выбиваются из общих данных, и/или таких выбивающихся очень мало для нормального обучения.

# %% [markdown]
# ## Улучшение нейронной сети разбиением на батчи и введением регуляризации

# %% [markdown]
# ### Добавление разбиения на батчи

# %%
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
torch.use_deterministic_algorithms(True)

class Net(nn.Module):
    def __init__(self, n_in_neurons, n_hidden_neurons_1, n_hidden_neurons_2, n_out_neurons):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(n_in_neurons, n_hidden_neurons_1)
        self.act1 = nn.Tanh()
        self.fc2 = nn.Linear(n_hidden_neurons_1, n_hidden_neurons_2)
        self.act2 = nn.ReLU()
        self.fc3 = nn.Linear(n_hidden_neurons_2, n_out_neurons)        
        self.act3 = nn.ReLU()
        
        # Инициализация весов
        nn.init.uniform_(self.fc1.weight, a=-1, b=1)
        nn.init.uniform_(self.fc1.bias, a=-1, b=3)
        nn.init.uniform_(self.fc2.weight, b=3)
        nn.init.uniform_(self.fc2.bias, a=-1)
        nn.init.uniform_(self.fc3.weight, b=2)
        nn.init.uniform_(self.fc3.bias, a=-1)

    def forward(self, x):
        x = self.fc1(x)
        x = self.act1(x)
        x = self.fc2(x)
        x = self.act2(x)
        x = self.fc3(x)
        x = self.act3(x)
        return x
    
    
net = Net(11, 20, 20, 1) 
optimizer = torch.optim.Adam(net.parameters(), lr=0.05)
loss = nn.L1Loss()# инициализируйте функцию потерь

num_epochs = 2000
best_rmse1 = 10000
test_preds_best1 = 0
best_batch = 0

for batch_size in range(10, 200, 20):

    num_batches = ceil(len(x_train_tensor)/batch_size)

    for epoch in range(num_epochs):
        order = np.random.permutation(len(x_train_tensor))# создайте случайную перестановку индексов объектов
        for batch_idx in range(num_batches):
            start_index = batch_idx * batch_size# посчитайте номер стартового объекта батча
            optimizer.zero_grad()
  
            batch_indexes = order[start_index:start_index+batch_size]# извлеките индексы объектов текущего обатча
            X_batch = x_train_tensor[batch_indexes]
            y_batch = y_train_tensor[batch_indexes]
  
            preds = net.forward(X_batch).flatten()
             
            loss_value = loss(preds, y_batch)

            loss_value.backward()
            
            optimizer.step()    
    
   
        if epoch % 100 == 0 or epoch == num_epochs - 1:
            net.eval()
            test_preds = net.forward(x_test_tensor).flatten()
        
            rmse = mse()**0.5
            RMSE = rmse(test_preds, y_test_tensor)
    
            print(RMSE)
        
        if best_rmse1 > RMSE:
            best_rmse1 = torch.round(RMSE)
            test_preds_best1 = torch.round(test_preds)
            best_batch = batch_size
# Out:
# tensor(14612.3232, grad_fn=<PowBackward0>)
# tensor(5264.4600, grad_fn=<PowBackward0>)
# tensor(4911.0244, grad_fn=<PowBackward0>)
# tensor(5256.4644, grad_fn=<PowBackward0>)
# tensor(5602.3467, grad_fn=<PowBackward0>)
# tensor(5692.5381, grad_fn=<PowBackward0>)
# tensor(5088.3174, grad_fn=<PowBackward0>)
# tensor(5680.7598, grad_fn=<PowBackward0>)
# tensor(5776.2715, grad_fn=<PowBackward0>)
# tensor(5382.6099, grad_fn=<PowBackward0>)
# tensor(5365.9429, grad_fn=<PowBackward0>)
# tensor(5367.6113, grad_fn=<PowBackward0>)
# tensor(5585.1108, grad_fn=<PowBackward0>)
# tensor(5188.3784, grad_fn=<PowBackward0>)
# tensor(5723.1362, grad_fn=<PowBackward0>)
# tensor(5875.0405, grad_fn=<PowBackward0>)
# tensor(5668.8657, grad_fn=<PowBackward0>)
# tensor(5256.4033, grad_fn=<PowBackward0>)
# tensor(5540.3354, grad_fn=<PowBackward0>)
# tensor(4723.0991, grad_fn=<PowBackward0>)
# tensor(4712.6914, grad_fn=<PowBackward0>)
# tensor(4725.4229, grad_fn=<PowBackward0>)
# tensor(4826.1245, grad_fn=<PowBackward0>)
# tensor(4756.2061, grad_fn=<PowBackward0>)
# tensor(4990.2256, grad_fn=<PowBackward0>)
# tensor(5080.0522, grad_fn=<PowBackward0>)
# tensor(4976.6357, grad_fn=<PowBackward0>)
# tensor(5049.1294, grad_fn=<PowBackward0>)
# tensor(5101.2451, grad_fn=<PowBackward0>)
# tensor(4979.9990, grad_fn=<PowBackward0>)
# tensor(5037.6064, grad_fn=<PowBackward0>)
# tensor(5149.5435, grad_fn=<PowBackward0>)
# tensor(5107.1670, grad_fn=<PowBackward0>)
# tensor(5120.0430, grad_fn=<PowBackward0>)
# tensor(5116.5420, grad_fn=<PowBackward0>)
# tensor(4955.0020, grad_fn=<PowBackward0>)
# tensor(5084.2729, grad_fn=<PowBackward0>)
# tensor(5061.1455, grad_fn=<PowBackward0>)
# tensor(5046.2549, grad_fn=<PowBackward0>)
# tensor(5166.0376, grad_fn=<PowBackward0>)
# tensor(5096.9238, grad_fn=<PowBackward0>)
# tensor(5061.2373, grad_fn=<PowBackward0>)
# tensor(5078.5601, grad_fn=<PowBackward0>)
# tensor(4894.4204, grad_fn=<PowBackward0>)
# tensor(5044.3521, grad_fn=<PowBackward0>)
# tensor(4973.5234, grad_fn=<PowBackward0>)
# tensor(5060.7236, grad_fn=<PowBackward0>)
# tensor(5230.3687, grad_fn=<PowBackward0>)
# tensor(4962.4331, grad_fn=<PowBackward0>)
# tensor(5144.4297, grad_fn=<PowBackward0>)
# tensor(5118.9287, grad_fn=<PowBackward0>)
# tensor(5117.9375, grad_fn=<PowBackward0>)
# tensor(5098.4585, grad_fn=<PowBackward0>)
# tensor(5069.9585, grad_fn=<PowBackward0>)
# tensor(5062.5391, grad_fn=<PowBackward0>)
# tensor(5020.9634, grad_fn=<PowBackward0>)
# tensor(4968.7007, grad_fn=<PowBackward0>)
# tensor(5005.8867, grad_fn=<PowBackward0>)
# tensor(5025.2837, grad_fn=<PowBackward0>)
# tensor(5188.7520, grad_fn=<PowBackward0>)
# tensor(4945.5786, grad_fn=<PowBackward0>)
# tensor(5156.6455, grad_fn=<PowBackward0>)
# tensor(5078.2476, grad_fn=<PowBackward0>)
# tensor(4976.8921, grad_fn=<PowBackward0>)
# tensor(4932.0312, grad_fn=<PowBackward0>)
# tensor(5159.6777, grad_fn=<PowBackward0>)
# tensor(4665.0273, grad_fn=<PowBackward0>)
# tensor(4936.2197, grad_fn=<PowBackward0>)
# tensor(4932.8032, grad_fn=<PowBackward0>)
# tensor(5026.2217, grad_fn=<PowBackward0>)
# tensor(4892.8130, grad_fn=<PowBackward0>)
# tensor(5100.2563, grad_fn=<PowBackward0>)
# tensor(5108.0889, grad_fn=<PowBackward0>)
# tensor(5034.9126, grad_fn=<PowBackward0>)
# tensor(5283.4385, grad_fn=<PowBackward0>)
# tensor(5158.8696, grad_fn=<PowBackward0>)
# tensor(5135.8599, grad_fn=<PowBackward0>)
# tensor(4340.8696, grad_fn=<PowBackward0>)
# tensor(4975.4951, grad_fn=<PowBackward0>)
# tensor(5306.8325, grad_fn=<PowBackward0>)
# tensor(4724.8169, grad_fn=<PowBackward0>)
# tensor(5129.7656, grad_fn=<PowBackward0>)
# tensor(4905.9370, grad_fn=<PowBackward0>)
# tensor(5181.2910, grad_fn=<PowBackward0>)
# tensor(5132.6738, grad_fn=<PowBackward0>)
# tensor(5462.1318, grad_fn=<PowBackward0>)
# tensor(6300.3428, grad_fn=<PowBackward0>)
# tensor(5489.0645, grad_fn=<PowBackward0>)
# tensor(4936.6191, grad_fn=<PowBackward0>)
# tensor(4968.3843, grad_fn=<PowBackward0>)
# tensor(4686.4829, grad_fn=<PowBackward0>)
# tensor(5266.1973, grad_fn=<PowBackward0>)
# tensor(5904.9697, grad_fn=<PowBackward0>)
# tensor(5064.1523, grad_fn=<PowBackward0>)
# tensor(5109.3828, grad_fn=<PowBackward0>)
# tensor(5162.8545, grad_fn=<PowBackward0>)
# tensor(5032.5747, grad_fn=<PowBackward0>)

# %%
print()        
print('Лучшее RMSE: ', best_rmse1)
print()
print('Лучшее предсказание: ', test_preds_best1)
print()
print('Тестовые данные: ', y_test_tensor)   
print()
print('Лучший размер Батча: ', best_batch)
# Out:
# Лучшее RMSE:  tensor(4339., grad_fn=<RoundBackward0>)
#
# Лучшее предсказание:  tensor([28308., 34022., 13075.,  3576., 13073.,  2907., 18076., 15908., 20463.,
#          3576., 21536.,  7214.,  3320.,  9597.,  3359., 13071., 13107.,  3576.,
#          9596.,  2926., 24121., 19236., 22473.,  5280., 28325., 13115., 36719.,
#         21599., 21292.,  3334.,  3576., 18212.,  3592., 21384.,  3578.,  3079.,
#          4296.,  3576.,  3599.,  3315.,  3590., 34726.,  2994.,  2963.,  2977.,
#         22925.,  8916., 13863.], grad_fn=<RoundBackward0>)
#
# Тестовые данные:  tensor([32489., 39000.,  9320.,  3834.,  9030.,  3218., 22012., 11250., 19860.,
#          3574., 18340.,  3614.,  3150.,  8250.,  3100., 25000.,  8945.,  3459.,
#          9700.,  2945., 27739., 17120., 11096.,  4980., 30839., 11000., 29560.,
#         16787.,  5752.,  3462.,  3826., 19360.,  3607., 24630.,  3615.,  2700.,
#          3570.,  3450.,  3490.,  2799.,  3650., 37800.,  2889.,  2774.,  3323.,
#         33421.,  7700., 13023.])
#
# Лучший размер Батча:  50

# %% [markdown]
# Разбиение на батчи улучшило показатель RMSE.

# %% [markdown]
# ### Добавим регуляризацию Dropout

# %%
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
torch.use_deterministic_algorithms(True)

num_epochs = 2000
best_rmse2 = 10000
test_preds_best2 = 0
best_batch1 = 0
best_Dropout = 0

for dp in range(4, 10, 1):

    class Net(nn.Module):
        def __init__(self, n_in_neurons, n_hidden_neurons_1, n_hidden_neurons_2, n_out_neurons):
            super(Net, self).__init__()
            self.fc1 = nn.Linear(n_in_neurons, n_hidden_neurons_1)
            self.act1 = nn.Tanh()
            self.dp1 = nn.Dropout(p=dp/10)
            self.fc2 = nn.Linear(n_hidden_neurons_1, n_hidden_neurons_2)
            self.act2 = nn.ReLU()
            self.dp2 = nn.Dropout(p=dp/10)    
            self.fc3 = nn.Linear(n_hidden_neurons_2, n_out_neurons)        
            self.act3 = nn.ReLU()
        
            # Инициализация весов
            nn.init.uniform_(self.fc1.weight, a=-1, b=1)
            nn.init.uniform_(self.fc1.bias, a=-1, b=3)
            nn.init.uniform_(self.fc2.weight, b=3)
            nn.init.uniform_(self.fc2.bias, a=-1)
            nn.init.uniform_(self.fc3.weight, b=2)
            nn.init.uniform_(self.fc3.bias, a=-1)

        def forward(self, x):
            x = self.fc1(x)
            x = self.act1(x)
            x = self.dp1(x)
            x = self.fc2(x)
            x = self.act2(x)
            x = self.dp2(x)
            x = self.fc3(x)
            x = self.act3(x)
            return x
    
    
    net = Net(11, 20, 20, 1) 
    optimizer = torch.optim.Adam(net.parameters(), lr=0.05)
    loss = nn.L1Loss()# инициализируйте функцию потерь

    for batch_size in range(10, 200, 20):

        num_batches = ceil(len(x_train_tensor)/batch_size)

        for epoch in range(num_epochs):
            order = np.random.permutation(len(x_train_tensor))# создайте случайную перестановку индексов объектов
            for batch_idx in range(num_batches):
                start_index = batch_idx * batch_size# посчитайте номер стартового объекта батча
                optimizer.zero_grad()
  
                batch_indexes = order[start_index:start_index+batch_size]# извлеките индексы объектов текущего обатча
                X_batch = x_train_tensor[batch_indexes]
                y_batch = y_train_tensor[batch_indexes]
  
                preds = net.forward(X_batch).flatten()
             
                loss_value = loss(preds, y_batch)

                loss_value.backward()
            
                optimizer.step()    
    
   
            if epoch % 100 == 0 or epoch == num_epochs - 1:
                net.eval()
                test_preds = net.forward(x_test_tensor).flatten()
        
                rmse = mse()**0.5
                RMSE = rmse(test_preds, y_test_tensor)
    
                print(RMSE)
        
            if best_rmse2 > RMSE:
                best_rmse2 = torch.round(RMSE)
                test_preds_best2 = torch.round(test_preds)
                best_batch1 = batch_size
                best_Dropout = dp/10
# Out:
# tensor(14692.2588, grad_fn=<PowBackward0>)
# tensor(5702.7783, grad_fn=<PowBackward0>)
# tensor(4572.7915, grad_fn=<PowBackward0>)
# tensor(4939.7686, grad_fn=<PowBackward0>)
# tensor(4942.5815, grad_fn=<PowBackward0>)
# tensor(4849.4072, grad_fn=<PowBackward0>)
# tensor(4729.3682, grad_fn=<PowBackward0>)
# tensor(4985.4546, grad_fn=<PowBackward0>)
# tensor(4598.7031, grad_fn=<PowBackward0>)
# tensor(4934.8062, grad_fn=<PowBackward0>)
# tensor(4955.5303, grad_fn=<PowBackward0>)
# tensor(5028.2842, grad_fn=<PowBackward0>)
# tensor(4838.2617, grad_fn=<PowBackward0>)
# tensor(4962.5439, grad_fn=<PowBackward0>)
# tensor(4824.2603, grad_fn=<PowBackward0>)
# tensor(4755.7119, grad_fn=<PowBackward0>)
# tensor(4756.3862, grad_fn=<PowBackward0>)
# tensor(4932.7842, grad_fn=<PowBackward0>)
# tensor(4960.7671, grad_fn=<PowBackward0>)
# tensor(4843.4482, grad_fn=<PowBackward0>)
# tensor(4993.7036, grad_fn=<PowBackward0>)
# tensor(4898.0996, grad_fn=<PowBackward0>)
# tensor(4979.6978, grad_fn=<PowBackward0>)
# tensor(4991.5566, grad_fn=<PowBackward0>)
# tensor(5372.2515, grad_fn=<PowBackward0>)
# tensor(5276.0244, grad_fn=<PowBackward0>)
# tensor(5330.6802, grad_fn=<PowBackward0>)
# tensor(5322.0024, grad_fn=<PowBackward0>)
# tensor(5321.9517, grad_fn=<PowBackward0>)
# tensor(5367.4810, grad_fn=<PowBackward0>)
# tensor(5351.4248, grad_fn=<PowBackward0>)
# tensor(5316.5220, grad_fn=<PowBackward0>)
# tensor(5351.2344, grad_fn=<PowBackward0>)
# tensor(5421.2227, grad_fn=<PowBackward0>)
# tensor(5385.5645, grad_fn=<PowBackward0>)
# tensor(5321.1206, grad_fn=<PowBackward0>)
# tensor(5282.4248, grad_fn=<PowBackward0>)
# tensor(5360.6812, grad_fn=<PowBackward0>)
# tensor(5423.1626, grad_fn=<PowBackward0>)
# tensor(5340.5859, grad_fn=<PowBackward0>)
# tensor(5198.0903, grad_fn=<PowBackward0>)
# tensor(5355.6846, grad_fn=<PowBackward0>)
# tensor(5262.0645, grad_fn=<PowBackward0>)
# tensor(5357.7075, grad_fn=<PowBackward0>)
# tensor(5363.9263, grad_fn=<PowBackward0>)
# tensor(5341.4453, grad_fn=<PowBackward0>)
# tensor(5418.0698, grad_fn=<PowBackward0>)
# tensor(5376.7007, grad_fn=<PowBackward0>)
# tensor(5407.2212, grad_fn=<PowBackward0>)
# tensor(5366.1914, grad_fn=<PowBackward0>)
# tensor(5374.5063, grad_fn=<PowBackward0>)
# tensor(5428.7183, grad_fn=<PowBackward0>)
# tensor(5295.8208, grad_fn=<PowBackward0>)
# tensor(5397.2773, grad_fn=<PowBackward0>)
# tensor(5242.5288, grad_fn=<PowBackward0>)
# tensor(5237.2388, grad_fn=<PowBackward0>)
# tensor(5445.9995, grad_fn=<PowBackward0>)
# tensor(5438.4639, grad_fn=<PowBackward0>)
# tensor(5096.7524, grad_fn=<PowBackward0>)
# tensor(5339.6943, grad_fn=<PowBackward0>)
# tensor(5188.7324, grad_fn=<PowBackward0>)
# tensor(5420.9980, grad_fn=<PowBackward0>)
# tensor(5375.9014, grad_fn=<PowBackward0>)
# tensor(5448.4082, grad_fn=<PowBackward0>)
# tensor(5292.2280, grad_fn=<PowBackward0>)
# tensor(5244.4517, grad_fn=<PowBackward0>)
# tensor(5178.6001, grad_fn=<PowBackward0>)
# tensor(5402.1655, grad_fn=<PowBackward0>)
# tensor(5190.6343, grad_fn=<PowBackward0>)
# tensor(5224.8418, grad_fn=<PowBackward0>)
# tensor(5394.1772, grad_fn=<PowBackward0>)
# tensor(5197.0386, grad_fn=<PowBackward0>)
# tensor(5109.6929, grad_fn=<PowBackward0>)
# tensor(5197.7021, grad_fn=<PowBackward0>)
# tensor(5124.3091, grad_fn=<PowBackward0>)
# tensor(5149.4551, grad_fn=<PowBackward0>)
# tensor(5272.7852, grad_fn=<PowBackward0>)
# tensor(4793.3193, grad_fn=<PowBackward0>)
# tensor(5280.9907, grad_fn=<PowBackward0>)
# tensor(5892.1938, grad_fn=<PowBackward0>)
# tensor(5094.2876, grad_fn=<PowBackward0>)
# tensor(5742.9653, grad_fn=<PowBackward0>)
# tensor(5695.9312, grad_fn=<PowBackward0>)
# tensor(5683.0352, grad_fn=<PowBackward0>)
# tensor(5780.3335, grad_fn=<PowBackward0>)
# tensor(5732.9346, grad_fn=<PowBackward0>)
# tensor(5787.3066, grad_fn=<PowBackward0>)
# tensor(5768.4980, grad_fn=<PowBackward0>)
# tensor(5867.5171, grad_fn=<PowBackward0>)
# tensor(5892.8521, grad_fn=<PowBackward0>)
# tensor(5891.4565, grad_fn=<PowBackward0>)
# tensor(5840.0957, grad_fn=<PowBackward0>)
# tensor(5819.1865, grad_fn=<PowBackward0>)
# tensor(5964.5381, grad_fn=<PowBackward0>)
# tensor(5904.8496, grad_fn=<PowBackward0>)
# tensor(5819.2441, grad_fn=<PowBackward0>)
# tensor(5864.1978, grad_fn=<PowBackward0>)
# tensor(5851.1792, grad_fn=<PowBackward0>)
# tensor(5680.2344, grad_fn=<PowBackward0>)
# tensor(5905.9722, grad_fn=<PowBackward0>)
# tensor(5890.8496, grad_fn=<PowBackward0>)
# tensor(5711.0508, grad_fn=<PowBackward0>)
# tensor(5680.0210, grad_fn=<PowBackward0>)
# tensor(5611.9102, grad_fn=<PowBackward0>)
# tensor(5734.3652, grad_fn=<PowBackward0>)
# tensor(5766.2383, grad_fn=<PowBackward0>)
# tensor(5843.1484, grad_fn=<PowBackward0>)
# tensor(5767.2979, grad_fn=<PowBackward0>)
# tensor(5879.9805, grad_fn=<PowBackward0>)
# tensor(5836.5190, grad_fn=<PowBackward0>)
# tensor(5813.4790, grad_fn=<PowBackward0>)
# tensor(5799.7627, grad_fn=<PowBackward0>)
# tensor(5740.8916, grad_fn=<PowBackward0>)
# tensor(5960.5854, grad_fn=<PowBackward0>)
# tensor(5763.6836, grad_fn=<PowBackward0>)
# tensor(5830.8501, grad_fn=<PowBackward0>)
# tensor(5700.0381, grad_fn=<PowBackward0>)
# tensor(5762.0869, grad_fn=<PowBackward0>)
# tensor(5632.4473, grad_fn=<PowBackward0>)
# tensor(5498.5249, grad_fn=<PowBackward0>)
# tensor(5798.0713, grad_fn=<PowBackward0>)
# tensor(5579.7983, grad_fn=<PowBackward0>)
# tensor(6082.5254, grad_fn=<PowBackward0>)
# tensor(5561.9170, grad_fn=<PowBackward0>)
# tensor(5796.2935, grad_fn=<PowBackward0>)
# tensor(5601.0264, grad_fn=<PowBackward0>)
# tensor(6571.6768, grad_fn=<PowBackward0>)
# tensor(7601.0625, grad_fn=<PowBackward0>)
# tensor(8685.0381, grad_fn=<PowBackward0>)
# tensor(6039.9058, grad_fn=<PowBackward0>)
# tensor(7497.7139, grad_fn=<PowBackward0>)
# tensor(7200.6113, grad_fn=<PowBackward0>)
# tensor(7382.0352, grad_fn=<PowBackward0>)
# tensor(8546.9746, grad_fn=<PowBackward0>)
# tensor(7915.4038, grad_fn=<PowBackward0>)
# tensor(8392.8594, grad_fn=<PowBackward0>)
# tensor(7127.6196, grad_fn=<PowBackward0>)
# tensor(7069.9917, grad_fn=<PowBackward0>)
# tensor(15002.7129, grad_fn=<PowBackward0>)
# tensor(6102.0933, grad_fn=<PowBackward0>)
# tensor(5378.4170, grad_fn=<PowBackward0>)
# tensor(5280.0220, grad_fn=<PowBackward0>)
# tensor(5612.0137, grad_fn=<PowBackward0>)
# tensor(5335.5859, grad_fn=<PowBackward0>)
# tensor(5358.2163, grad_fn=<PowBackward0>)
# tensor(5935.9258, grad_fn=<PowBackward0>)
# tensor(5547.3735, grad_fn=<PowBackward0>)
# tensor(5363.1587, grad_fn=<PowBackward0>)
# tensor(6140.9697, grad_fn=<PowBackward0>)
# tensor(5325.9209, grad_fn=<PowBackward0>)
# tensor(5868.6406, grad_fn=<PowBackward0>)
# tensor(5763.3052, grad_fn=<PowBackward0>)
# tensor(6057.9312, grad_fn=<PowBackward0>)
# tensor(6501.7529, grad_fn=<PowBackward0>)
# tensor(5904.8237, grad_fn=<PowBackward0>)
# tensor(5739.6875, grad_fn=<PowBackward0>)
# tensor(5764.8423, grad_fn=<PowBackward0>)
# tensor(5750.5269, grad_fn=<PowBackward0>)
# tensor(5760.8340, grad_fn=<PowBackward0>)
# tensor(5914.8535, grad_fn=<PowBackward0>)
# tensor(5552.2710, grad_fn=<PowBackward0>)
# tensor(5678.0435, grad_fn=<PowBackward0>)
# tensor(5578.6582, grad_fn=<PowBackward0>)
# tensor(5549.8828, grad_fn=<PowBackward0>)
# tensor(5577.0469, grad_fn=<PowBackward0>)
# tensor(5547.7017, grad_fn=<PowBackward0>)
# tensor(5579.3101, grad_fn=<PowBackward0>)
# tensor(5625.3901, grad_fn=<PowBackward0>)
# tensor(5649.6924, grad_fn=<PowBackward0>)
# tensor(5574.2705, grad_fn=<PowBackward0>)
# tensor(5629.1201, grad_fn=<PowBackward0>)
# tensor(5641.9175, grad_fn=<PowBackward0>)
# tensor(5641.4023, grad_fn=<PowBackward0>)
# tensor(5674.0322, grad_fn=<PowBackward0>)
# tensor(5638.8159, grad_fn=<PowBackward0>)
# tensor(5519.5039, grad_fn=<PowBackward0>)
# tensor(5827.0547, grad_fn=<PowBackward0>)
# tensor(5809.6411, grad_fn=<PowBackward0>)
# tensor(5588.7168, grad_fn=<PowBackward0>)
# tensor(5791.8516, grad_fn=<PowBackward0>)
# tensor(5787.2017, grad_fn=<PowBackward0>)
# tensor(5882.3716, grad_fn=<PowBackward0>)
# tensor(5774.1343, grad_fn=<PowBackward0>)
# tensor(5765.5908, grad_fn=<PowBackward0>)
# tensor(5755.9116, grad_fn=<PowBackward0>)
# tensor(5720.5913, grad_fn=<PowBackward0>)
# tensor(5793.2290, grad_fn=<PowBackward0>)
# tensor(5784.3540, grad_fn=<PowBackward0>)
# tensor(5860.4707, grad_fn=<PowBackward0>)
# tensor(5802.6758, grad_fn=<PowBackward0>)
# tensor(5797.7573, grad_fn=<PowBackward0>)
# tensor(5799.0649, grad_fn=<PowBackward0>)
# tensor(5820.7178, grad_fn=<PowBackward0>)
# tensor(5790.9028, grad_fn=<PowBackward0>)
# tensor(5776.4399, grad_fn=<PowBackward0>)
# tensor(5663.8306, grad_fn=<PowBackward0>)
# tensor(5723.5122, grad_fn=<PowBackward0>)
# tensor(5675.6729, grad_fn=<PowBackward0>)
# tensor(5696.9888, grad_fn=<PowBackward0>)
# tensor(5663.3872, grad_fn=<PowBackward0>)
# tensor(5672.3779, grad_fn=<PowBackward0>)
# tensor(5667.7578, grad_fn=<PowBackward0>)
# tensor(5705.4253, grad_fn=<PowBackward0>)
# tensor(5694.1338, grad_fn=<PowBackward0>)
# tensor(5678.6865, grad_fn=<PowBackward0>)
# tensor(5670.5703, grad_fn=<PowBackward0>)
# tensor(5706.9404, grad_fn=<PowBackward0>)
# tensor(5661.9331, grad_fn=<PowBackward0>)
# tensor(5653.3296, grad_fn=<PowBackward0>)
# tensor(5693.9673, grad_fn=<PowBackward0>)
# tensor(5699.4473, grad_fn=<PowBackward0>)
# tensor(5669.5312, grad_fn=<PowBackward0>)
# tensor(5677.4150, grad_fn=<PowBackward0>)
# tensor(5745.9380, grad_fn=<PowBackward0>)
# tensor(5699.8418, grad_fn=<PowBackward0>)
# tensor(5679.4165, grad_fn=<PowBackward0>)
# tensor(5654.9878, grad_fn=<PowBackward0>)
# tensor(5698.3906, grad_fn=<PowBackward0>)
# tensor(5630.9653, grad_fn=<PowBackward0>)
# tensor(5701.0962, grad_fn=<PowBackward0>)
# tensor(5652.3398, grad_fn=<PowBackward0>)
# tensor(5730.5903, grad_fn=<PowBackward0>)
# tensor(5679.4688, grad_fn=<PowBackward0>)
# tensor(5710.6348, grad_fn=<PowBackward0>)
# tensor(5754.1416, grad_fn=<PowBackward0>)
# tensor(5694.8481, grad_fn=<PowBackward0>)
# tensor(5698.9722, grad_fn=<PowBackward0>)
# tensor(5673.0283, grad_fn=<PowBackward0>)
# tensor(5685.7002, grad_fn=<PowBackward0>)
# tensor(5677.7158, grad_fn=<PowBackward0>)
# tensor(5769.7612, grad_fn=<PowBackward0>)
# tensor(5700.5859, grad_fn=<PowBackward0>)
# tensor(5767.1719, grad_fn=<PowBackward0>)
# tensor(5744.7622, grad_fn=<PowBackward0>)
# tensor(5698.7002, grad_fn=<PowBackward0>)
# tensor(5700.6826, grad_fn=<PowBackward0>)
# tensor(5692.9351, grad_fn=<PowBackward0>)
# tensor(5681.7153, grad_fn=<PowBackward0>)
# tensor(5697.5244, grad_fn=<PowBackward0>)
# tensor(5696.2744, grad_fn=<PowBackward0>)
# tensor(5622.0923, grad_fn=<PowBackward0>)
# tensor(5677.3403, grad_fn=<PowBackward0>)
# tensor(5637.0220, grad_fn=<PowBackward0>)
# tensor(5693.5332, grad_fn=<PowBackward0>)
# tensor(5694.4893, grad_fn=<PowBackward0>)
# tensor(5695.0430, grad_fn=<PowBackward0>)
# tensor(5617.0073, grad_fn=<PowBackward0>)
# tensor(5718.7017, grad_fn=<PowBackward0>)
# tensor(5641.6528, grad_fn=<PowBackward0>)
# tensor(5671.5312, grad_fn=<PowBackward0>)
# tensor(5674.1743, grad_fn=<PowBackward0>)
# tensor(5764.9800, grad_fn=<PowBackward0>)
# tensor(6109.9561, grad_fn=<PowBackward0>)
# tensor(6141.3428, grad_fn=<PowBackward0>)
# tensor(6164.0420, grad_fn=<PowBackward0>)
# tensor(6130.9829, grad_fn=<PowBackward0>)
# tensor(6075.3105, grad_fn=<PowBackward0>)
# tensor(6078.0249, grad_fn=<PowBackward0>)
# tensor(6104.6318, grad_fn=<PowBackward0>)
# tensor(6129.5483, grad_fn=<PowBackward0>)
# tensor(6141.1401, grad_fn=<PowBackward0>)
# tensor(6148.2393, grad_fn=<PowBackward0>)
# tensor(6151.1431, grad_fn=<PowBackward0>)
# tensor(6105.3833, grad_fn=<PowBackward0>)
# tensor(6133.2603, grad_fn=<PowBackward0>)
# tensor(6159.6470, grad_fn=<PowBackward0>)
# tensor(6089.2656, grad_fn=<PowBackward0>)
# tensor(6077.2568, grad_fn=<PowBackward0>)
# tensor(6125.8223, grad_fn=<PowBackward0>)
# tensor(6169.6860, grad_fn=<PowBackward0>)
# tensor(6105.2002, grad_fn=<PowBackward0>)
# tensor(6136.7061, grad_fn=<PowBackward0>)
# tensor(6128.4561, grad_fn=<PowBackward0>)
# tensor(6085.0811, grad_fn=<PowBackward0>)
# tensor(6007.4556, grad_fn=<PowBackward0>)
# tensor(6136.7388, grad_fn=<PowBackward0>)
# tensor(6139.8257, grad_fn=<PowBackward0>)
# tensor(6081.6025, grad_fn=<PowBackward0>)
# tensor(6161.8574, grad_fn=<PowBackward0>)
# tensor(6171.5884, grad_fn=<PowBackward0>)
# tensor(6158.1943, grad_fn=<PowBackward0>)
# tensor(6151.8467, grad_fn=<PowBackward0>)
# tensor(6111.0576, grad_fn=<PowBackward0>)
# tensor(6117.0112, grad_fn=<PowBackward0>)
# tensor(6132.6328, grad_fn=<PowBackward0>)
# tensor(6133.4824, grad_fn=<PowBackward0>)
# tensor(6163.3784, grad_fn=<PowBackward0>)
# tensor(6062.2954, grad_fn=<PowBackward0>)
# tensor(6125.8887, grad_fn=<PowBackward0>)
# tensor(6165.8193, grad_fn=<PowBackward0>)
# tensor(6195.4106, grad_fn=<PowBackward0>)
# tensor(6138.6235, grad_fn=<PowBackward0>)
# tensor(6258.5127, grad_fn=<PowBackward0>)
# tensor(6087.3965, grad_fn=<PowBackward0>)
# tensor(6113.1611, grad_fn=<PowBackward0>)
# tensor(5824.3940, grad_fn=<PowBackward0>)
# tensor(6067.7266, grad_fn=<PowBackward0>)
# tensor(6198.6362, grad_fn=<PowBackward0>)
# tensor(5963.0713, grad_fn=<PowBackward0>)
# tensor(6063.5186, grad_fn=<PowBackward0>)
# tensor(6075.6270, grad_fn=<PowBackward0>)
# tensor(6180.7305, grad_fn=<PowBackward0>)
# tensor(6068.8613, grad_fn=<PowBackward0>)
# tensor(6063.1689, grad_fn=<PowBackward0>)
# tensor(6214.4014, grad_fn=<PowBackward0>)
# tensor(6109.2256, grad_fn=<PowBackward0>)
# tensor(6126.2422, grad_fn=<PowBackward0>)
# tensor(6125.3994, grad_fn=<PowBackward0>)
# tensor(5232.9912, grad_fn=<PowBackward0>)
# tensor(5267.6196, grad_fn=<PowBackward0>)
# tensor(5176.5674, grad_fn=<PowBackward0>)
# tensor(5433.2407, grad_fn=<PowBackward0>)
# tensor(5332.3091, grad_fn=<PowBackward0>)
# tensor(5354.9448, grad_fn=<PowBackward0>)
# tensor(5128.7275, grad_fn=<PowBackward0>)
# tensor(5543.8271, grad_fn=<PowBackward0>)
# tensor(5295.5732, grad_fn=<PowBackward0>)
# tensor(5236.3608, grad_fn=<PowBackward0>)
# tensor(5518.6279, grad_fn=<PowBackward0>)
# tensor(5553.3921, grad_fn=<PowBackward0>)
# tensor(5733.3770, grad_fn=<PowBackward0>)
# tensor(5683.0078, grad_fn=<PowBackward0>)
# tensor(5503.4146, grad_fn=<PowBackward0>)
# tensor(5736.1113, grad_fn=<PowBackward0>)
# tensor(5601.5693, grad_fn=<PowBackward0>)
# tensor(5684.3018, grad_fn=<PowBackward0>)
# tensor(5634.5542, grad_fn=<PowBackward0>)
# tensor(5481.0830, grad_fn=<PowBackward0>)
# tensor(5471.5376, grad_fn=<PowBackward0>)
# tensor(5740.4028, grad_fn=<PowBackward0>)
# tensor(5543.5049, grad_fn=<PowBackward0>)
# tensor(5658.6733, grad_fn=<PowBackward0>)
# tensor(5534.2871, grad_fn=<PowBackward0>)
# tensor(5701.0752, grad_fn=<PowBackward0>)
# tensor(5580.6431, grad_fn=<PowBackward0>)
# tensor(5468.3789, grad_fn=<PowBackward0>)
# tensor(5555.7622, grad_fn=<PowBackward0>)
# tensor(5771.0908, grad_fn=<PowBackward0>)
# tensor(5642.0806, grad_fn=<PowBackward0>)
# tensor(5579.7915, grad_fn=<PowBackward0>)
# tensor(5573.9844, grad_fn=<PowBackward0>)
# tensor(5524.9917, grad_fn=<PowBackward0>)
# tensor(5469.6479, grad_fn=<PowBackward0>)
# tensor(5484.0483, grad_fn=<PowBackward0>)
# tensor(5563.1797, grad_fn=<PowBackward0>)
# tensor(5631.1011, grad_fn=<PowBackward0>)
# tensor(5521.9199, grad_fn=<PowBackward0>)
# tensor(5591.9956, grad_fn=<PowBackward0>)
# tensor(5569.6221, grad_fn=<PowBackward0>)
# tensor(5544.8604, grad_fn=<PowBackward0>)
# tensor(5537.8091, grad_fn=<PowBackward0>)
# tensor(5441.9844, grad_fn=<PowBackward0>)
# tensor(5536.9248, grad_fn=<PowBackward0>)
# tensor(5594.0098, grad_fn=<PowBackward0>)
# tensor(5516.7095, grad_fn=<PowBackward0>)
# tensor(5568.0625, grad_fn=<PowBackward0>)
# tensor(5557.0825, grad_fn=<PowBackward0>)
# tensor(5499.3677, grad_fn=<PowBackward0>)
# tensor(5553.8486, grad_fn=<PowBackward0>)
# tensor(5541.3706, grad_fn=<PowBackward0>)
# tensor(5606.3384, grad_fn=<PowBackward0>)
# tensor(5677.3369, grad_fn=<PowBackward0>)
# tensor(5468.3955, grad_fn=<PowBackward0>)
# tensor(5372.5649, grad_fn=<PowBackward0>)
# tensor(5843.0723, grad_fn=<PowBackward0>)
# tensor(5743.2334, grad_fn=<PowBackward0>)
# tensor(5725.6445, grad_fn=<PowBackward0>)
# tensor(5390.7202, grad_fn=<PowBackward0>)
# tensor(5618.6738, grad_fn=<PowBackward0>)
# tensor(5493.2202, grad_fn=<PowBackward0>)
# tensor(5579.4897, grad_fn=<PowBackward0>)
# tensor(5440.3589, grad_fn=<PowBackward0>)
# tensor(5510.1318, grad_fn=<PowBackward0>)
# tensor(5422.8687, grad_fn=<PowBackward0>)
# tensor(5986.1255, grad_fn=<PowBackward0>)
# tensor(5363.6899, grad_fn=<PowBackward0>)
# tensor(5675.6572, grad_fn=<PowBackward0>)
# tensor(5767.4053, grad_fn=<PowBackward0>)
# tensor(5597.0557, grad_fn=<PowBackward0>)
# tensor(6303.4087, grad_fn=<PowBackward0>)
# tensor(6342.6353, grad_fn=<PowBackward0>)
# tensor(5747.4893, grad_fn=<PowBackward0>)
# tensor(5843.4360, grad_fn=<PowBackward0>)
# tensor(5782.9243, grad_fn=<PowBackward0>)
# tensor(5768.8872, grad_fn=<PowBackward0>)
# tensor(5773.1245, grad_fn=<PowBackward0>)
# tensor(5825.8042, grad_fn=<PowBackward0>)
# tensor(5823.3457, grad_fn=<PowBackward0>)
# tensor(5786.5137, grad_fn=<PowBackward0>)
# tensor(5838.3301, grad_fn=<PowBackward0>)
# tensor(5872.1890, grad_fn=<PowBackward0>)
# tensor(5867.8032, grad_fn=<PowBackward0>)
# tensor(5783.3750, grad_fn=<PowBackward0>)
# tensor(5715.7690, grad_fn=<PowBackward0>)
# tensor(5721.5386, grad_fn=<PowBackward0>)
# tensor(5700.4189, grad_fn=<PowBackward0>)
# tensor(5719.2812, grad_fn=<PowBackward0>)
# tensor(5705.5244, grad_fn=<PowBackward0>)
# tensor(5818.6538, grad_fn=<PowBackward0>)
# tensor(5761.5186, grad_fn=<PowBackward0>)
# tensor(5769.2661, grad_fn=<PowBackward0>)
# tensor(5794.9766, grad_fn=<PowBackward0>)
# tensor(5718.0659, grad_fn=<PowBackward0>)
# tensor(5869.0850, grad_fn=<PowBackward0>)
# tensor(5781.6406, grad_fn=<PowBackward0>)
# tensor(5623.7153, grad_fn=<PowBackward0>)
# tensor(5650.6006, grad_fn=<PowBackward0>)
# tensor(5820.2915, grad_fn=<PowBackward0>)
# tensor(5667.6030, grad_fn=<PowBackward0>)
# tensor(5753.0225, grad_fn=<PowBackward0>)
# tensor(5686.4126, grad_fn=<PowBackward0>)
# tensor(5763.0083, grad_fn=<PowBackward0>)
# tensor(5794.6377, grad_fn=<PowBackward0>)
# tensor(5782.9556, grad_fn=<PowBackward0>)
# tensor(5716.3638, grad_fn=<PowBackward0>)
# tensor(5735.8931, grad_fn=<PowBackward0>)
# tensor(5775.1362, grad_fn=<PowBackward0>)
# tensor(5692.1772, grad_fn=<PowBackward0>)
# tensor(5865.7329, grad_fn=<PowBackward0>)
# tensor(5655.4629, grad_fn=<PowBackward0>)
# tensor(5730.3359, grad_fn=<PowBackward0>)
# tensor(5725.5317, grad_fn=<PowBackward0>)
# tensor(5698.4229, grad_fn=<PowBackward0>)
# tensor(5702.5459, grad_fn=<PowBackward0>)
# tensor(5660.1533, grad_fn=<PowBackward0>)
# tensor(5765.0693, grad_fn=<PowBackward0>)
# tensor(5612.4438, grad_fn=<PowBackward0>)
# tensor(5703.0659, grad_fn=<PowBackward0>)
# tensor(5963.3555, grad_fn=<PowBackward0>)
# tensor(5829.3267, grad_fn=<PowBackward0>)
# tensor(5623.2197, grad_fn=<PowBackward0>)
# tensor(5591.1050, grad_fn=<PowBackward0>)
# tensor(5710.7134, grad_fn=<PowBackward0>)
# tensor(5754.9995, grad_fn=<PowBackward0>)
# tensor(5748.6216, grad_fn=<PowBackward0>)
# tensor(5841.1382, grad_fn=<PowBackward0>)
# tensor(5694.2632, grad_fn=<PowBackward0>)
# tensor(5536.1240, grad_fn=<PowBackward0>)
# tensor(5810.2642, grad_fn=<PowBackward0>)
# tensor(5745.4419, grad_fn=<PowBackward0>)
# tensor(5871.0781, grad_fn=<PowBackward0>)
# tensor(5811.0815, grad_fn=<PowBackward0>)
# tensor(5764.7881, grad_fn=<PowBackward0>)
# tensor(5742.7324, grad_fn=<PowBackward0>)
# tensor(5465.7817, grad_fn=<PowBackward0>)
# tensor(5569.3521, grad_fn=<PowBackward0>)
# tensor(5507.4570, grad_fn=<PowBackward0>)
# tensor(5490.1089, grad_fn=<PowBackward0>)
# tensor(5768.3750, grad_fn=<PowBackward0>)
# tensor(5511.8735, grad_fn=<PowBackward0>)
# tensor(5641.3823, grad_fn=<PowBackward0>)
# tensor(5670.4492, grad_fn=<PowBackward0>)
# tensor(5509.9019, grad_fn=<PowBackward0>)
# tensor(5419.4189, grad_fn=<PowBackward0>)
# tensor(5375.4634, grad_fn=<PowBackward0>)
# tensor(5428.4150, grad_fn=<PowBackward0>)
# tensor(5575.0229, grad_fn=<PowBackward0>)
# tensor(5924.6606, grad_fn=<PowBackward0>)
# tensor(5537.8511, grad_fn=<PowBackward0>)
# tensor(5919.2646, grad_fn=<PowBackward0>)
# tensor(5544.5190, grad_fn=<PowBackward0>)
# tensor(5693.0298, grad_fn=<PowBackward0>)
# tensor(5775.2402, grad_fn=<PowBackward0>)
# tensor(5305.7715, grad_fn=<PowBackward0>)
# tensor(5470.5640, grad_fn=<PowBackward0>)
# tensor(6420.8345, grad_fn=<PowBackward0>)
# tensor(6153.1621, grad_fn=<PowBackward0>)
# tensor(5689.0913, grad_fn=<PowBackward0>)
# tensor(5181.2969, grad_fn=<PowBackward0>)
# tensor(5204.8589, grad_fn=<PowBackward0>)
# tensor(5513.1689, grad_fn=<PowBackward0>)
# tensor(5403.3794, grad_fn=<PowBackward0>)
# tensor(5161.9941, grad_fn=<PowBackward0>)
# tensor(5486.7085, grad_fn=<PowBackward0>)
# tensor(5227.0522, grad_fn=<PowBackward0>)
# tensor(6239.9053, grad_fn=<PowBackward0>)
# tensor(5469.2690, grad_fn=<PowBackward0>)
# tensor(5681.5146, grad_fn=<PowBackward0>)
# tensor(5097.8027, grad_fn=<PowBackward0>)
# tensor(5462.4312, grad_fn=<PowBackward0>)
# tensor(6677.4644, grad_fn=<PowBackward0>)
# tensor(5146.3960, grad_fn=<PowBackward0>)
# tensor(4893.0073, grad_fn=<PowBackward0>)
# tensor(5640.3110, grad_fn=<PowBackward0>)
# tensor(4982.2612, grad_fn=<PowBackward0>)
# tensor(15586.0684, grad_fn=<PowBackward0>)
# tensor(5877.3169, grad_fn=<PowBackward0>)
# tensor(4587.9961, grad_fn=<PowBackward0>)
# tensor(4847.3647, grad_fn=<PowBackward0>)
# tensor(4673.5913, grad_fn=<PowBackward0>)
# tensor(4845.0381, grad_fn=<PowBackward0>)
# tensor(5412.0547, grad_fn=<PowBackward0>)
# tensor(5118.9795, grad_fn=<PowBackward0>)
# tensor(6052.4341, grad_fn=<PowBackward0>)
# tensor(5234.5859, grad_fn=<PowBackward0>)
# tensor(5488.8955, grad_fn=<PowBackward0>)
# tensor(5219.1929, grad_fn=<PowBackward0>)
# tensor(5425.7925, grad_fn=<PowBackward0>)
# tensor(5173.1816, grad_fn=<PowBackward0>)
# tensor(5257.3804, grad_fn=<PowBackward0>)
# tensor(5069.6758, grad_fn=<PowBackward0>)
# tensor(5115.3999, grad_fn=<PowBackward0>)
# tensor(5163.8589, grad_fn=<PowBackward0>)
# tensor(5326.4648, grad_fn=<PowBackward0>)
# tensor(5159.5996, grad_fn=<PowBackward0>)
# tensor(5356.3696, grad_fn=<PowBackward0>)
# tensor(5339.0840, grad_fn=<PowBackward0>)
# tensor(5222.8442, grad_fn=<PowBackward0>)
# tensor(5185.8203, grad_fn=<PowBackward0>)
# tensor(5301.0122, grad_fn=<PowBackward0>)
# tensor(5100.3535, grad_fn=<PowBackward0>)
# tensor(5174.1108, grad_fn=<PowBackward0>)
# tensor(5286.0557, grad_fn=<PowBackward0>)
# tensor(5255.7593, grad_fn=<PowBackward0>)
# tensor(5214.3950, grad_fn=<PowBackward0>)
# tensor(5159.1948, grad_fn=<PowBackward0>)
# tensor(5197.5430, grad_fn=<PowBackward0>)
# tensor(5326.9595, grad_fn=<PowBackward0>)
# tensor(5235.2476, grad_fn=<PowBackward0>)
# tensor(5214.0562, grad_fn=<PowBackward0>)
# tensor(5229.9111, grad_fn=<PowBackward0>)
# tensor(5302.6450, grad_fn=<PowBackward0>)
# tensor(5224.9600, grad_fn=<PowBackward0>)
# tensor(5306.4233, grad_fn=<PowBackward0>)
# tensor(5219.7100, grad_fn=<PowBackward0>)
# tensor(5169.3027, grad_fn=<PowBackward0>)
# tensor(5311.5073, grad_fn=<PowBackward0>)
# tensor(5345.4194, grad_fn=<PowBackward0>)
# tensor(5550.5449, grad_fn=<PowBackward0>)
# tensor(5565.0820, grad_fn=<PowBackward0>)
# tensor(5611.9082, grad_fn=<PowBackward0>)
# tensor(5480.3335, grad_fn=<PowBackward0>)
# tensor(5505.3125, grad_fn=<PowBackward0>)
# tensor(5547.6943, grad_fn=<PowBackward0>)
# tensor(5526.0327, grad_fn=<PowBackward0>)
# tensor(5493.5830, grad_fn=<PowBackward0>)
# tensor(5509.4253, grad_fn=<PowBackward0>)
# tensor(5508.5396, grad_fn=<PowBackward0>)
# tensor(5497.3535, grad_fn=<PowBackward0>)
# tensor(5539.2251, grad_fn=<PowBackward0>)
# tensor(5547.5181, grad_fn=<PowBackward0>)
# tensor(5438.8477, grad_fn=<PowBackward0>)
# tensor(5529.6255, grad_fn=<PowBackward0>)
# tensor(5506.8569, grad_fn=<PowBackward0>)
# tensor(5558.5996, grad_fn=<PowBackward0>)
# tensor(5474.9888, grad_fn=<PowBackward0>)
# tensor(5510.6963, grad_fn=<PowBackward0>)
# tensor(5482.4468, grad_fn=<PowBackward0>)
# tensor(5522.7739, grad_fn=<PowBackward0>)
# tensor(5578.6069, grad_fn=<PowBackward0>)
# tensor(5563.4727, grad_fn=<PowBackward0>)
# tensor(5510.0503, grad_fn=<PowBackward0>)
# tensor(5544.9019, grad_fn=<PowBackward0>)
# tensor(5611.5635, grad_fn=<PowBackward0>)
# tensor(5653.8164, grad_fn=<PowBackward0>)
# tensor(5622.0684, grad_fn=<PowBackward0>)
# tensor(5518.0083, grad_fn=<PowBackward0>)
# tensor(5578.2129, grad_fn=<PowBackward0>)
# tensor(5575.7168, grad_fn=<PowBackward0>)
# tensor(5595.7681, grad_fn=<PowBackward0>)
# tensor(5535.3345, grad_fn=<PowBackward0>)
# tensor(5517.7676, grad_fn=<PowBackward0>)
# tensor(5547.2676, grad_fn=<PowBackward0>)
# tensor(5557.3936, grad_fn=<PowBackward0>)
# tensor(5577.2344, grad_fn=<PowBackward0>)
# tensor(5560.1895, grad_fn=<PowBackward0>)
# tensor(5558.0918, grad_fn=<PowBackward0>)
# tensor(5534.0610, grad_fn=<PowBackward0>)
# tensor(5568.5063, grad_fn=<PowBackward0>)
# tensor(5567.3652, grad_fn=<PowBackward0>)
# tensor(5833.3330, grad_fn=<PowBackward0>)
# tensor(5587.1948, grad_fn=<PowBackward0>)
# tensor(5551.0864, grad_fn=<PowBackward0>)
# tensor(5455.3511, grad_fn=<PowBackward0>)
# tensor(5496.3799, grad_fn=<PowBackward0>)
# tensor(5479.4087, grad_fn=<PowBackward0>)
# tensor(5387.2388, grad_fn=<PowBackward0>)
# tensor(5439.3398, grad_fn=<PowBackward0>)
# tensor(5390.7300, grad_fn=<PowBackward0>)
# tensor(5471.1230, grad_fn=<PowBackward0>)
# tensor(5507.6665, grad_fn=<PowBackward0>)
# tensor(5499.2065, grad_fn=<PowBackward0>)
# tensor(5439.1890, grad_fn=<PowBackward0>)
# tensor(5472.4673, grad_fn=<PowBackward0>)
# tensor(5501.4238, grad_fn=<PowBackward0>)
# tensor(5564.4170, grad_fn=<PowBackward0>)
# tensor(5804.3311, grad_fn=<PowBackward0>)
# tensor(5377.6646, grad_fn=<PowBackward0>)
# tensor(5442.0664, grad_fn=<PowBackward0>)
# tensor(5571.9814, grad_fn=<PowBackward0>)
# tensor(5545.7959, grad_fn=<PowBackward0>)
# tensor(5535.2080, grad_fn=<PowBackward0>)
# tensor(5575.9541, grad_fn=<PowBackward0>)
# tensor(5536.6250, grad_fn=<PowBackward0>)
# tensor(5538.9121, grad_fn=<PowBackward0>)
# tensor(5530.0498, grad_fn=<PowBackward0>)
# tensor(5524.6221, grad_fn=<PowBackward0>)
# tensor(5512.5225, grad_fn=<PowBackward0>)
# tensor(5543.5449, grad_fn=<PowBackward0>)
# tensor(5558.7920, grad_fn=<PowBackward0>)
# tensor(5568.2251, grad_fn=<PowBackward0>)
# tensor(5598.2554, grad_fn=<PowBackward0>)
# tensor(5592.5225, grad_fn=<PowBackward0>)
# tensor(5662.4453, grad_fn=<PowBackward0>)
# tensor(5614.3652, grad_fn=<PowBackward0>)
# tensor(5609.6938, grad_fn=<PowBackward0>)
# tensor(5595.8208, grad_fn=<PowBackward0>)
# tensor(5592.7314, grad_fn=<PowBackward0>)
# tensor(5597.6782, grad_fn=<PowBackward0>)
# tensor(5552.2173, grad_fn=<PowBackward0>)
# tensor(5624.0693, grad_fn=<PowBackward0>)
# tensor(5625.0835, grad_fn=<PowBackward0>)
# tensor(5550.4272, grad_fn=<PowBackward0>)
# tensor(5531.1221, grad_fn=<PowBackward0>)
# tensor(5549.5083, grad_fn=<PowBackward0>)
# tensor(5504.3306, grad_fn=<PowBackward0>)
# tensor(5617.3452, grad_fn=<PowBackward0>)
# tensor(5550.2222, grad_fn=<PowBackward0>)
# tensor(5571.0059, grad_fn=<PowBackward0>)
# tensor(5535.4180, grad_fn=<PowBackward0>)
# tensor(5573.9331, grad_fn=<PowBackward0>)
# tensor(5705.5679, grad_fn=<PowBackward0>)
# tensor(5611.1299, grad_fn=<PowBackward0>)
# tensor(5606.1582, grad_fn=<PowBackward0>)
# tensor(5552.2373, grad_fn=<PowBackward0>)
# tensor(5667.8716, grad_fn=<PowBackward0>)
# tensor(5542.2886, grad_fn=<PowBackward0>)
# tensor(5585.3838, grad_fn=<PowBackward0>)
# tensor(5591.0952, grad_fn=<PowBackward0>)
# tensor(5634.3115, grad_fn=<PowBackward0>)
# tensor(5613.6128, grad_fn=<PowBackward0>)
# tensor(5579.7061, grad_fn=<PowBackward0>)
# tensor(5601.6460, grad_fn=<PowBackward0>)
# tensor(5566.0034, grad_fn=<PowBackward0>)
# tensor(5582.4893, grad_fn=<PowBackward0>)
# tensor(5589.8257, grad_fn=<PowBackward0>)
# tensor(5453.8350, grad_fn=<PowBackward0>)
# tensor(5574.8818, grad_fn=<PowBackward0>)
# tensor(5487.7266, grad_fn=<PowBackward0>)
# tensor(5529.7378, grad_fn=<PowBackward0>)
# tensor(5566.7007, grad_fn=<PowBackward0>)
# tensor(5461.9868, grad_fn=<PowBackward0>)
# tensor(5582.2075, grad_fn=<PowBackward0>)
# tensor(5551.7563, grad_fn=<PowBackward0>)
# tensor(5489.7803, grad_fn=<PowBackward0>)
# tensor(5540.7900, grad_fn=<PowBackward0>)
# tensor(5558.2715, grad_fn=<PowBackward0>)
# tensor(5476.0781, grad_fn=<PowBackward0>)
# tensor(5516.9946, grad_fn=<PowBackward0>)
# tensor(5541.9219, grad_fn=<PowBackward0>)
# tensor(5544.1787, grad_fn=<PowBackward0>)
# tensor(5539.9277, grad_fn=<PowBackward0>)
# tensor(5594.6343, grad_fn=<PowBackward0>)
# tensor(5558.2075, grad_fn=<PowBackward0>)
# tensor(5464.5293, grad_fn=<PowBackward0>)
# tensor(5661.0142, grad_fn=<PowBackward0>)
# tensor(5593.4282, grad_fn=<PowBackward0>)
# tensor(5529.8110, grad_fn=<PowBackward0>)
# tensor(5662.7856, grad_fn=<PowBackward0>)
# tensor(5527.0635, grad_fn=<PowBackward0>)
# tensor(5584.9023, grad_fn=<PowBackward0>)
# tensor(5446.5444, grad_fn=<PowBackward0>)
# tensor(5552.0786, grad_fn=<PowBackward0>)
# tensor(5485.1851, grad_fn=<PowBackward0>)
# tensor(5535.2759, grad_fn=<PowBackward0>)
# tensor(5465.5684, grad_fn=<PowBackward0>)
# tensor(5841.2407, grad_fn=<PowBackward0>)
# tensor(5541.9556, grad_fn=<PowBackward0>)
# tensor(5551.5669, grad_fn=<PowBackward0>)
# tensor(5505.0918, grad_fn=<PowBackward0>)
# tensor(5581.5996, grad_fn=<PowBackward0>)
# tensor(5579.5317, grad_fn=<PowBackward0>)
# tensor(5388.8662, grad_fn=<PowBackward0>)
# tensor(5444.1929, grad_fn=<PowBackward0>)
# tensor(5454.0054, grad_fn=<PowBackward0>)
# tensor(5540.1040, grad_fn=<PowBackward0>)
# tensor(6012.1167, grad_fn=<PowBackward0>)
# tensor(4802.4429, grad_fn=<PowBackward0>)
# tensor(4703.2563, grad_fn=<PowBackward0>)
# tensor(6283.2661, grad_fn=<PowBackward0>)
# tensor(5970.0723, grad_fn=<PowBackward0>)
# tensor(5391.5972, grad_fn=<PowBackward0>)
# tensor(6272.2329, grad_fn=<PowBackward0>)
# tensor(6298.3457, grad_fn=<PowBackward0>)
# tensor(6354.7700, grad_fn=<PowBackward0>)
# tensor(5944.4268, grad_fn=<PowBackward0>)
# tensor(6298.4307, grad_fn=<PowBackward0>)
# tensor(6440.0200, grad_fn=<PowBackward0>)
# tensor(6361.9014, grad_fn=<PowBackward0>)
# tensor(5995.3794, grad_fn=<PowBackward0>)
# tensor(5954.3286, grad_fn=<PowBackward0>)
# tensor(6662.5913, grad_fn=<PowBackward0>)
# tensor(5924.4639, grad_fn=<PowBackward0>)
# tensor(5889.0923, grad_fn=<PowBackward0>)
# tensor(6147.7715, grad_fn=<PowBackward0>)

# %%
print()        
print('Лучшее RMSE: ', best_rmse2)
print()
print('Лучшее предсказание: ', test_preds_best2)
print()
print('Тестовые данные: ', y_test_tensor) 
print()
print('Лучший размер Батча: ', best_batch1) 
print()
print('Лучший гиперпараметр Dropout: ', best_Dropout)
# Out:
# Лучшее RMSE:  tensor(4375., grad_fn=<RoundBackward0>)
#
# Лучшее предсказание:  tensor([35212., 33389., 12868.,  3456., 12866.,  2989., 18568., 18509., 22340.,
#          3355., 22878.,  3553.,  3291.,  8587.,  3294., 11128., 12954.,  3456.,
#          8587.,  2997., 21865., 14630., 17905.,  5288., 29797., 24463., 28475.,
#         17060., 17104.,  3292.,  3355., 19660.,  3420., 22385.,  3456.,  2997.,
#          3872.,  3456.,  3456.,  3293.,  3734., 33424.,  2997.,  2997.,  2997.,
#         22933.,  7130., 17009.], grad_fn=<RoundBackward0>)
#
# Тестовые данные:  tensor([32489., 39000.,  9320.,  3834.,  9030.,  3218., 22012., 11250., 19860.,
#          3574., 18340.,  3614.,  3150.,  8250.,  3100., 25000.,  8945.,  3459.,
#          9700.,  2945., 27739., 17120., 11096.,  4980., 30839., 11000., 29560.,
#         16787.,  5752.,  3462.,  3826., 19360.,  3607., 24630.,  3615.,  2700.,
#          3570.,  3450.,  3490.,  2799.,  3650., 37800.,  2889.,  2774.,  3323.,
#         33421.,  7700., 13023.])
#
# Лучший размер Батча:  190
#
# Лучший гиперпараметр Dropout:  0.4

# %% [markdown]
# ### Сравнение Факт - Прогноз, график.

# %%
index = np.arange(48)
values1 = y_test_tensor.tolist()
values2 = test_preds_best1.tolist()
plt.figure(figsize=(16, 8))
plt.title('График сравнения фактической и предсказанной температуры звезд.')
plt.bar(index, values1, alpha=0.6, label='ФАКТ', width=0.9)
plt.bar(index, values2, alpha=0.7, label='ПРОГНОЗ Torch', width=0.6)
plt.legend()
plt.xlabel('Номер звезды')
plt.ylabel('Температура К')
plt.show();

# %% [markdown]
# ## Сравнение метрик RMSE и параметров

# %%
compare = pd.DataFrame(data=[['Лучший RMSE', result_cr, best_rmse.tolist(), best_rmse1.tolist(), best_rmse2.tolist()],
                            ['Лучший размер Батча', 'Нет', 'Нет', best_batch, best_batch1],
                            ['Лучший параметр Dropout', 'Нет', 'Нет', 'Нет', best_Dropout]],
                   columns=['Параметр','Классика CatBoostRegressor', 'Базовое обучение нейросети',
                            'Обучение нейросети с батчами', 'Обучение нейросети с батчами и Dropout'])
display(compare)
# Out:
#                   Параметр Классика CatBoostRegressor  \
# 0              Лучший RMSE                    5604.81
# 1      Лучший размер Батча                        Нет
# 2  Лучший параметр Dropout                        Нет
#
#   Базовое обучение нейросети Обучение нейросети с батчами  \
# 0                       4425                         4339
# 1                        Нет                           50
# 2                        Нет                          Нет
#
#    Обучение нейросети с батчами и Dropout
# 0                                  4375.0
# 1                                   190.0
# 2                                     0.4

# %% [markdown]
# ## <b>Общие выводы</b>

# %% [markdown]
# * В таблице всего 240 строк и наибольшее количество звезд по показателям ближе к земному Солнцу - мало данных с большими параметрами.
#
#
# * Именно в диапазоне ближе к Солнечным наблюдается наибольшая точность предсказаний
#
#
# * При надлежащем терпении, по подбору различных параметров нейросети, можно уже на базовой модели достигнуть высоких показателей точности предсказаний:
#
#
# * Точность предсказаний модели нейросети выше точности предсказаний классического обучения
#
#
# * Обучение нейросети с разбиением обучающих данных на батчи повышает точность предсказаний
#
#
# * Введение регуляризации Dropout особо не сказалось на точности предсказаний, видимо из-за малого количества обучающих данных, переобучение не сильно влияет на результат предсказаний
